# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('myexcel - myexcel.csv.csv')

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # The data consist of 458 rows and 9 columns.

# %% [markdown]
# # 1

# %%
df['Height']=np.random.randint(150,180,size=len(df))

# %%
df['Height']
# Out:
# 0      179
# 1      179
# 2      176
# 3      172
# 4      161
#       ...
# 453    164
# 454    169
# 455    176
# 456    150
# 457    162
# Name: Height, Length: 458, dtype: int32

# %% [markdown]
# # 2

# %%
total_employees=df['Team'].value_counts().sum()

# %%
total_employees
# Out:
# 458

# %%
employee_distribution = df['Team'].value_counts()

# %%
employee_distribution
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
percentage_split_of_employee = (employee_distribution)/(total_employees)*100

# %%
percentage_split_of_employee
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
employee_distribution.plot(kind='hist',color='b')
plt.xlabel('Number of players')
plt.ylabel('Teams')
plt.title('Players and their Team')
plt.show()

# %% [markdown]
# # 3

# %%
employees = df['Position'].value_counts()

# %%
employees
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
employees.plot(kind='pie')
plt.legend(title = 'Players position',loc ='lower right')
plt.show()

# %% [markdown]
# # 4

# %%
predominant_age_group = df['Age'].value_counts().idxmax()
predominant_age_group
# Out:
# 24

# %% [markdown]
# # Most players are of age 24.

# %%
df['Age'].plot(kind='hist',color='green',edgecolor='yellow')
plt.xlabel('Age')
plt.ylabel('Number of players')
plt.title('Players Age')
plt.show()

# %% [markdown]
# # 5

# %%
highest_salary = df.loc[df['Salary'].idxmax()][['Name','Position','Team','Salary']]
highest_salary
# Out:
# Name               Kobe Bryant
# Position                    SF
# Team        Los Angeles Lakers
# Salary              25000000.0
# Name: 109, dtype: object

# %% [markdown]
# # Kobe Bryant is the player who is getting high salary.

# %%
df['Salary'].plot(kind='hist',color='brown')
plt.xlabel('Salary in(thousands of dollars)')
plt.ylabel('Players')
plt.title('Salary of Players')
plt.show()

# %% [markdown]
# # 6

# %%
sns.scatterplot(x=df['Age'],y =df['Salary'],hue= df['Salary'],data ='myexcel - myexcel.csv.csv')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Correlation of Salary and Age')
plt.show()

# %% [markdown]
# # The dataset from ABC company consisting 458 rows and 9 columns.ABC company has 458 employees.
